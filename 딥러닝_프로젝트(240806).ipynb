# %% [markdown]
# <a href="https://colab.research.google.com/github/mseoulum/AIFFEL_Quest/blob/main/%EB%94%A5%EB%9F%AC%EB%8B%9D_%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8(240806).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Boston 주택 가격 예측 모델

# %% [markdown]
# ## 데이터 로드 및 전처리

# %%
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
# keras.datasets 안에 boston_housing 데이터셋을 로드합니다.
from keras.datasets import boston_housing

(train_data, train_labels), (test_data, test_labels) = boston_housing.load_data()

# 데이터셋의 크기를 확인합니다.
print(len(train_data))
print(len(test_data))
# Out:
# 404
# 102

# %%
# 문제 1-1: 데이터셋의 전처리를 위해 표준화 작업을 수행합니다.
# 먼저 입력 데이터의 각 특성의 평균을 뺍니다.
mean = train_data.mean(axis=0)
train_data = train_data - mean

# 평균을 뺀 입력 데이터에서 표준편차를 나눕니다.
# 데이터 특성의 중앙이 0에 가깝게 만들고, 표준편차가 1이 되게 만듭니다.
std = train_data.std(axis=0)
train_data = train_data / std

# 테스트 데이터셋도 마찬가지로 평균을 빼고, 표준편차로 나눕니다.
test_data = test_data - mean
test_data = test_data / std

# %% [markdown]
# ## 모델 구성 및 컴파일

# %%
# 문제 1-2: 주택 가격 예측을 위한 딥러닝 모델 구성 및 컴파일합니다.
# input_shape은 (train_data.shape[1], )으로 구성합니다.
# 회귀(예측)을 위한 모델이므로 loss를 mse, metrics를 mae로 사용합니다.
model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(train_data.shape[1],)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1))

model.compile(optimizer='adam', loss='mse', metrics=['mae'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## 모델 학습

# %%
# 문제 1-3: 예측을 위한 딥러닝 모델을 학습합니다.
history = model.fit(train_data, train_labels,
                    epochs=100,
                    batch_size=32,
                    validation_split=0.2)
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 604.3308 - mae: 22.5085 - val_loss: 593.0585 - val_mae: 22.5649
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 502.4706 - mae: 20.3415 - val_loss: 541.5389 - val_mae: 21.3702
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 456.0108 - mae: 19.2028 - val_loss: 478.1436 - val_mae: 19.8636
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 414.8244 - mae: 17.9450 - val_loss: 397.5249 - val_mae: 17.8406
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 329.2309 - mae: 15.7119 - val_loss: 302.4995 - val_mae: 15.2226
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 222.6467 - mae: 12.7397 - val_loss: 203.4439 - val_mae: 12.0686
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 150.2479 - mae: 10.1023 - val_loss: 120.5865 - val_mae: 8.6978
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 94.3516 - mae: 7.8408 - val_loss: 75.1828 - val_mae: 6.6800
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 55.3999 - mae: 5.8135 - val_loss: 56.5979 - val_mae: 5.7472
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 44.1615 - mae: 5.0571 - val_loss: 45.5848 - val_mae: 5.1315
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 43.8677 - mae: 4.8196 - val_loss: 38.0493 - val_mae: 4.6280
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 35.4484 - mae: 4.2993 - val_loss: 33.3989 - val_mae: 4.2539
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.0188 - mae: 3.8918 - val_loss: 29.1564 - val_mae: 3.9999
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.0797 - mae: 3.4571 - val_loss: 26.7780 - val_mae: 3.8487
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.0699 - mae: 3.6929 - val_loss: 25.2857 - val_mae: 3.7284
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25.3625 - mae: 3.4756 - val_loss: 23.8398 - val_mae: 3.6081
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 25.9142 - mae: 3.3008 - val_loss: 22.5089 - val_mae: 3.4887
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.3668 - mae: 3.1585 - val_loss: 21.3440 - val_mae: 3.4128
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.5523 - mae: 2.9801 - val_loss: 20.6728 - val_mae: 3.3572
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.9837 - mae: 2.9443 - val_loss: 20.1465 - val_mae: 3.3439
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.2799 - mae: 2.9725 - val_loss: 19.6507 - val_mae: 3.2951
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.1150 - mae: 2.8834 - val_loss: 18.9671 - val_mae: 3.2064
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.4333 - mae: 2.7184 - val_loss: 18.4212 - val_mae: 3.1525
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.5698 - mae: 2.8603 - val_loss: 17.9357 - val_mae: 3.1288
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.8266 - mae: 2.5831 - val_loss: 17.5439 - val_mae: 3.0999
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.5639 - mae: 2.6861 - val_loss: 17.1059 - val_mae: 3.0412
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.2927 - mae: 2.8735 - val_loss: 16.7826 - val_mae: 3.0111
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.5233 - mae: 2.9911 - val_loss: 16.5626 - val_mae: 2.9986
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.0490 - mae: 2.7057 - val_loss: 16.3501 - val_mae: 3.0168
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.3826 - mae: 2.5725 - val_loss: 16.3305 - val_mae: 3.0020
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.4612 - mae: 2.8156 - val_loss: 15.9157 - val_mae: 2.9248
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.5075 - mae: 2.5547 - val_loss: 15.2217 - val_mae: 2.8550
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.5606 - mae: 2.4776 - val_loss: 14.9955 - val_mae: 2.8414
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.9642 - mae: 2.5396 - val_loss: 14.8704 - val_mae: 2.8398
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.9580 - mae: 2.5626 - val_loss: 14.7703 - val_mae: 2.8354
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.1851 - mae: 2.5048 - val_loss: 14.9743 - val_mae: 2.9015
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.5774 - mae: 2.2932 - val_loss: 14.4898 - val_mae: 2.8306
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.0447 - mae: 2.4369 - val_loss: 14.2772 - val_mae: 2.7876
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.8270 - mae: 2.3336 - val_loss: 14.1906 - val_mae: 2.7911
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.4720 - mae: 2.4155 - val_loss: 14.2969 - val_mae: 2.8349
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.4557 - mae: 2.2850 - val_loss: 14.2686 - val_mae: 2.8074
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.8624 - mae: 2.5072 - val_loss: 14.2017 - val_mae: 2.7660
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.0831 - mae: 2.2579 - val_loss: 13.7356 - val_mae: 2.7367
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.1603 - mae: 2.2011 - val_loss: 13.7766 - val_mae: 2.7566
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.1937 - mae: 2.2860 - val_loss: 13.8205 - val_mae: 2.7555
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5367 - mae: 2.2208 - val_loss: 13.8232 - val_mae: 2.7543
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.5339 - mae: 2.2505 - val_loss: 13.3695 - val_mae: 2.6730
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9189 - mae: 2.2315 - val_loss: 13.2492 - val_mae: 2.6460
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7010 - mae: 2.2352 - val_loss: 13.3970 - val_mae: 2.6974
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.1580 - mae: 2.1450 - val_loss: 13.4825 - val_mae: 2.6648
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.4324 - mae: 2.1309 - val_loss: 13.5876 - val_mae: 2.7175
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.3224 - mae: 2.3168 - val_loss: 13.4274 - val_mae: 2.6589
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.1942 - mae: 2.2888 - val_loss: 13.3764 - val_mae: 2.6581
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.7444 - mae: 2.0931 - val_loss: 13.2507 - val_mae: 2.6563
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 11.4188 - mae: 2.2453 - val_loss: 13.4296 - val_mae: 2.6634
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 11.1146 - mae: 2.2442 - val_loss: 13.3901 - val_mae: 2.6489
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.9906 - mae: 2.1830 - val_loss: 13.2408 - val_mae: 2.6082
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7823 - mae: 2.1170 - val_loss: 13.0751 - val_mae: 2.5974
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 10.7426 - mae: 2.1434 - val_loss: 13.2566 - val_mae: 2.6408
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0966 - mae: 2.1661 - val_loss: 13.1011 - val_mae: 2.6213
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7446 - mae: 2.0693 - val_loss: 13.0513 - val_mae: 2.6282
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0014 - mae: 2.1071 - val_loss: 13.0621 - val_mae: 2.6258
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.3572 - mae: 2.1403 - val_loss: 12.7492 - val_mae: 2.6246
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.3888 - mae: 2.2661 - val_loss: 13.1106 - val_mae: 2.6047
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.3979 - mae: 2.0294 - val_loss: 13.1437 - val_mae: 2.6041
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.8146 - mae: 2.1925 - val_loss: 13.0778 - val_mae: 2.5933
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.8612 - mae: 2.0391 - val_loss: 13.1913 - val_mae: 2.5766
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.0860 - mae: 2.1144 - val_loss: 13.3846 - val_mae: 2.5589
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.8296 - mae: 2.2472 - val_loss: 15.5119 - val_mae: 2.6810
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.1733 - mae: 2.2499 - val_loss: 14.4312 - val_mae: 2.6068
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7176 - mae: 2.1899 - val_loss: 14.0716 - val_mae: 2.6006
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3659 - mae: 2.0324 - val_loss: 13.8257 - val_mae: 2.5945
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.4603 - mae: 2.0528 - val_loss: 13.9898 - val_mae: 2.5832
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7684 - mae: 2.1711 - val_loss: 14.0232 - val_mae: 2.5784
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.4834 - mae: 2.1264 - val_loss: 13.7256 - val_mae: 2.5520
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.6124 - mae: 2.1019 - val_loss: 13.7541 - val_mae: 2.5902
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7445 - mae: 2.0598 - val_loss: 13.2721 - val_mae: 2.5291
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.8634 - mae: 2.0362 - val_loss: 13.6096 - val_mae: 2.5401
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.5512 - mae: 1.9768 - val_loss: 13.4924 - val_mae: 2.5473
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.6277 - mae: 2.0362 - val_loss: 13.7118 - val_mae: 2.5738
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.6736 - mae: 2.0695 - val_loss: 13.6485 - val_mae: 2.5501
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.9926 - mae: 2.0595 - val_loss: 13.5640 - val_mae: 2.5411
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5645 - mae: 1.9885 - val_loss: 13.7238 - val_mae: 2.5552
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.0382 - mae: 2.0169 - val_loss: 13.8838 - val_mae: 2.5648
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6992 - mae: 2.0278 - val_loss: 13.4355 - val_mae: 2.5178
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.1585 - mae: 1.9141 - val_loss: 13.4319 - val_mae: 2.5145
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.7800 - mae: 1.9808 - val_loss: 13.3849 - val_mae: 2.5370
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.6130 - mae: 1.9435 - val_loss: 13.5270 - val_mae: 2.5387
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.7696 - mae: 1.9363 - val_loss: 13.3807 - val_mae: 2.5372
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.1722 - mae: 1.9835 - val_loss: 13.7015 - val_mae: 2.5598
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.3082 - mae: 2.0677 - val_loss: 13.9963 - val_mae: 2.6146
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.3293 - mae: 2.1139 - val_loss: 13.8389 - val_mae: 2.5945
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.6719 - mae: 1.9788 - val_loss: 13.6116 - val_mae: 2.5532
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.8693 - mae: 1.9402 - val_loss: 13.6993 - val_mae: 2.5541
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.1495 - mae: 2.0620 - val_loss: 14.0408 - val_mae: 2.5701
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.8302 - mae: 1.9864 - val_loss: 13.9546 - val_mae: 2.5672
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6477 - mae: 1.9133 - val_loss: 14.0506 - val_mae: 2.5566
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.1136 - mae: 1.9840 - val_loss: 13.8673 - val_mae: 2.5374
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6351 - mae: 1.8947 - val_loss: 13.6928 - val_mae: 2.5544
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.3018 - mae: 1.9645 - val_loss: 13.8622 - val_mae: 2.5696

# %%
# 모델 학습 히스토리에서 loss, val_loss, mae, val_mae를 차트로 보여줍니다.
plt.style.use('seaborn-white')

history_dict = history.history

loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b-', label='train_loss')
ax1.plot(epochs, val_loss, 'r-', label='val_loss')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

mae = history_dict['mae']
val_mae = history_dict['val_mae']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, mae, 'b-', label='train_mae')
ax2.plot(epochs, val_mae, 'r-', label='val_mae')
ax2.set_title('Train and Validation MAE')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()
# Out:
# <ipython-input-6-eee1a1311e5a>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')

# %% [markdown]
# ## 모델 평가 및 예측

# %%
# 문제 1-4: 테스트 데이터셋을 이용해 모델을 평가합니다.
test_loss, test_mae = model.evaluate(test_data, test_labels)

print(f"Test Loss: {test_loss:.3f}")
print(f"Test MAE: {test_mae:.3f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.5092 - mae: 2.8748
# Test Loss: 25.141
# Test MAE: 3.076

# %% [markdown]
# # Reuters 딥러닝 모델

# %% [markdown]
# ## 데이터 로드 및 전처리

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras import models, layers
from tensorflow.keras import callbacks
from tensorflow.keras import utils
from keras.datasets import reuters

# %%
# 문제 2-1: reuters 데이터셋을 로드하고, 훈련 데이터셋에서 25%를 검증 데이터셋으로 분리합니다.
(train_data, train_labels), (test_data, test_labels) = reuters.load_data(num_words=10000)

# 훈련 데이터셋에서 25%를 검증 데이터셋으로 분리
train_data, val_data, train_labels, val_labels = train_test_split(train_data, train_labels, test_size=0.25, random_state=42)

# 훈련, 검증, 테스트 데이터와 레이블 종류가 몇 개인지 출력합니다.
print(len(train_data))
print(len(val_data))
print(len(test_data))
print(len(set(train_labels)))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# 6736
# 2246
# 2246
# 46

# %%
# 문제 2-2: 텍스트 데이터의 전처리를 위해서 각 데이터셋마다 원-핫 인코딩을 수행합니다.
def one_hot_encoding(data, dimension=10000):
    results = np.zeros((len(data), dimension))
    for i, sequence in enumerate(data):
        results[i, sequence] = 1
    return results

x_train = one_hot_encoding(train_data)
x_val = one_hot_encoding(val_data)
x_test = one_hot_encoding(test_data)

# 레이블 데이터들은 범주형 형태로 to_categorical() 함수를 사용해 변환합니다.
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(train_labels)
y_val = to_categorical(val_labels)
y_test = to_categorical(test_labels)

# %% [markdown]
# ## 모델 구성 및 컴파일

# %%
# 문제 2-3: 빠른 학습과 과대적합을 방지하기 위해 BatchNormalization과 Dropout을 적용한 딥러닝 모델을 구성합니다.
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization

model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(10000,)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(46, activation='softmax'))  # 46개의 주제 분류를 위한 출력층

# 모델 컴파일
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 64)                  │         640,064 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 46)                  │           2,990 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 647,726 (2.47 MB)
#  Trainable params: 647,470 (2.47 MB)
#  Non-trainable params: 256 (1.00 KB)

# %% [markdown]
# ## 모델 학습

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# ModelCheckpoint 설정
# checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True, monitor='val_loss', mode='min')
checkpoint = ModelCheckpoint('best_model.keras', save_best_only=True, monitor='val_loss', mode='min')

# EarlyStopping 설정
early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1)

# 문제 2-4: ModelCheckpoint와 EarlyStopping 콜백 함수를 적용하여 모델 학습을 진행합니다.
history = model.fit(x_train, y_train,
                    epochs=50,
                    batch_size=64,
                    validation_data=(x_val, y_val),
                    callbacks=[checkpoint, early_stopping])
# Out:
# Epoch 1/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.2908 - loss: 3.3692 - val_accuracy: 0.6300 - val_loss: 2.3127
# Epoch 2/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.6645 - loss: 1.6205 - val_accuracy: 0.6963 - val_loss: 1.5141
# Epoch 3/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7242 - loss: 1.2736 - val_accuracy: 0.7493 - val_loss: 1.1958
# Epoch 4/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7550 - loss: 1.0787 - val_accuracy: 0.7711 - val_loss: 1.0973
# Epoch 5/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7822 - loss: 0.9622 - val_accuracy: 0.7832 - val_loss: 1.0605
# Epoch 6/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.8062 - loss: 0.8342 - val_accuracy: 0.7916 - val_loss: 1.0372
# Epoch 7/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.8325 - loss: 0.7023 - val_accuracy: 0.7992 - val_loss: 1.0104
# Epoch 8/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8375 - loss: 0.6582 - val_accuracy: 0.7992 - val_loss: 1.0193
# Epoch 9/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8531 - loss: 0.6213 - val_accuracy: 0.8081 - val_loss: 0.9996
# Epoch 10/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.8660 - loss: 0.5697 - val_accuracy: 0.7974 - val_loss: 1.0079
# Epoch 11/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.8732 - loss: 0.5072 - val_accuracy: 0.8050 - val_loss: 1.0204
# Epoch 12/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.8784 - loss: 0.5175 - val_accuracy: 0.8081 - val_loss: 1.0530
# Epoch 13/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8880 - loss: 0.4667 - val_accuracy: 0.8103 - val_loss: 1.0017
# Epoch 14/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.8915 - loss: 0.4384 - val_accuracy: 0.8050 - val_loss: 1.0347
# Epoch 14: early stopping

# %%
# 학습 히스토리의 `loss`, `val_loss`, `accuracy`, `val_accuracy`를 차트로 시각화합니다.
plt.style.use('seaborn-white')

history_dict = history.history

loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b-', label='train_loss')
ax1.plot(epochs, val_loss, 'r-', label='val_loss')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, accuracy, 'b-', label='train_accuracy')
ax2.plot(epochs, val_accuracy, 'r-', label='val_accuracy')
ax2.set_title('Train and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()
# Out:
# <ipython-input-17-ef4da0309378>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')

# %% [markdown]
# ## 모델 평가 및 예측

# %%
# 테스트 데이터셋을 이용해 모델을 평가합니다.
test_loss, test_accuracy = model.evaluate(x_test, y_test)

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7920 - loss: 1.1066
# Test Loss: 1.1272
# Test Accuracy: 0.7832

# %% [markdown]
# # CIFAR10 딥러닝 모델

# %% [markdown]
# ## 데이터 로드 및 전처리

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras import models, layers
from tensorflow.keras.datasets import cifar10

# %%
# 문제 3-1: cifar10 데이터셋을 로드하고, 훈련 데이터셋에서 20%를 검증 데이터셋으로 분리합니다.
(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()

x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size=0.2, random_state=42)

# 훈련, 검증, 테스트 데이터와 레이블 종류가 몇개인지 출력합니다.
print("전체 학습 데이터: {} 레이블: {}".format(x_train_full.shape, y_train_full.shape))
print("학습 데이터: {} 레이블: {}".format(x_train.shape, y_train.shape))
print("검증 데이터: {} 레이블: {}".format(x_val.shape, y_val.shape))
print("테스트 데이터: {} 레이블: {}".format(x_test.shape, y_test.shape))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# 전체 학습 데이터: (50000, 32, 32, 3) 레이블: (50000, 1)
# 학습 데이터: (40000, 32, 32, 3) 레이블: (40000, 1)
# 검증 데이터: (10000, 32, 32, 3) 레이블: (10000, 1)
# 테스트 데이터: (10000, 32, 32, 3) 레이블: (10000, 1)

# %%
# cifar10의 분류에 해당하는 'airplane', 'automobile', 'bird', 'cat', 'deer',
# 'dog', 'frog', 'horse', 'ship', 'truck'를 class_name으로 정의합니다.
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# 훈련 데이터의 0번째인 x_train[0]를 이미지로 시각화합니다.
plt.style.use('seaborn-white')

plt.figure()
plt.imshow(x_train[0])
plt.colorbar()
plt.show()
# Out:
# <ipython-input-22-6d8a43ba86bc>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')

# %%
# 훈련, 검증, 테스트 데이터의 형태(shape)을 출력합니다.
print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# (40000, 32, 32, 3)
# (10000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
# 문제 3-2: 훈련, 검증, 테스트 데이터의 형태(shape)을 32 * 32 * 3 = 3072로 변형합니다.
x_train = x_train.reshape((x_train.shape[0], 32 * 32 * 3))
x_val = x_val.reshape((x_val.shape[0], 32 * 32 * 3))
x_test = x_test.reshape((x_test.shape[0], 32 * 32 * 3))

print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# (40000, 3072)
# (10000, 3072)
# (10000, 3072)

# %%
# 훈련, 검증, 테스트 데이터를 255로 나누어 0~1 사이의 값으로 변환합니다.
x_train = x_train / 255.
x_val = x_val / 255.
x_test = x_test / 255.

# %% [markdown]
# ## 모델 구성 및 컴파일

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization

# 문제 3-3: BatchNormalization과 Dropout을 적용하여 빠른 학습과 과대적합을 방지하고,
# 10개의 이미지를 분류하는 딥러닝 모델을 구성합니다.
model = Sequential([
    Dense(512, activation='relu', input_shape=(32 * 32 * 3,)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

# 모델 컴파일
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_10 (Dense)                     │ (None, 512)                 │       1,573,376 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,742,474 (6.65 MB)
#  Trainable params: 1,740,682 (6.64 MB)
#  Non-trainable params: 1,792 (7.00 KB)

# %%
utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ## 모델 학습

# %%
# 문제 3-4: ModelCheckpoint와 EarlyStopping 콜백 함수를 적용하여 모델 학습을 진행합니다.
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

checkpoint = ModelCheckpoint('best_cifar10_model.keras', save_best_only=True, monitor='val_loss', mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

history = model.fit(x_train, y_train,
                    epochs=100,
                    batch_size=64,
                    validation_data=(x_val, y_val),
                    callbacks=[checkpoint, early_stopping])
# Out:
# Epoch 1/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.2081 - loss: 2.5478 - val_accuracy: 0.3094 - val_loss: 1.8717
# Epoch 2/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 36s 33ms/step - accuracy: 0.3189 - loss: 1.8900 - val_accuracy: 0.3377 - val_loss: 1.8215
# Epoch 3/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 43s 37ms/step - accuracy: 0.3428 - loss: 1.8260 - val_accuracy: 0.3659 - val_loss: 1.7469
# Epoch 4/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 36ms/step - accuracy: 0.3483 - loss: 1.8041 - val_accuracy: 0.3604 - val_loss: 1.7612
# Epoch 5/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 36ms/step - accuracy: 0.3485 - loss: 1.8028 - val_accuracy: 0.3799 - val_loss: 1.7360
# Epoch 6/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 33s 53ms/step - accuracy: 0.3576 - loss: 1.7948 - val_accuracy: 0.3898 - val_loss: 1.6892
# Epoch 7/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 29s 34ms/step - accuracy: 0.3504 - loss: 1.8041 - val_accuracy: 0.4096 - val_loss: 1.6396
# Epoch 8/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 40s 33ms/step - accuracy: 0.3587 - loss: 1.7854 - val_accuracy: 0.3894 - val_loss: 1.6813
# Epoch 9/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 43s 36ms/step - accuracy: 0.3659 - loss: 1.7653 - val_accuracy: 0.3804 - val_loss: 1.6789
# Epoch 10/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 37ms/step - accuracy: 0.3651 - loss: 1.7738 - val_accuracy: 0.4014 - val_loss: 1.6492
# Epoch 11/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 36ms/step - accuracy: 0.3643 - loss: 1.7689 - val_accuracy: 0.4038 - val_loss: 1.6466
# Epoch 12/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 36ms/step - accuracy: 0.3562 - loss: 1.7781 - val_accuracy: 0.4186 - val_loss: 1.6336
# Epoch 13/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 40s 35ms/step - accuracy: 0.3577 - loss: 1.7779 - val_accuracy: 0.3968 - val_loss: 1.6530
# Epoch 14/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 42s 36ms/step - accuracy: 0.3554 - loss: 1.7888 - val_accuracy: 0.4153 - val_loss: 1.6458
# Epoch 15/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - accuracy: 0.3606 - loss: 1.7767 - val_accuracy: 0.4205 - val_loss: 1.6380
# Epoch 16/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 42s 34ms/step - accuracy: 0.3588 - loss: 1.7839 - val_accuracy: 0.3936 - val_loss: 1.6738
# Epoch 17/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 42s 36ms/step - accuracy: 0.3656 - loss: 1.7604 - val_accuracy: 0.4134 - val_loss: 1.6315
# Epoch 18/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 40s 35ms/step - accuracy: 0.3703 - loss: 1.7559 - val_accuracy: 0.3894 - val_loss: 1.6655
# Epoch 19/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 36ms/step - accuracy: 0.3703 - loss: 1.7528 - val_accuracy: 0.4130 - val_loss: 1.6368
# Epoch 20/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 36ms/step - accuracy: 0.3656 - loss: 1.7551 - val_accuracy: 0.4036 - val_loss: 1.6540
# Epoch 21/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 40s 35ms/step - accuracy: 0.3674 - loss: 1.7586 - val_accuracy: 0.4112 - val_loss: 1.6167
# Epoch 22/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 42s 36ms/step - accuracy: 0.3655 - loss: 1.7528 - val_accuracy: 0.4212 - val_loss: 1.6214
# Epoch 23/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 40s 34ms/step - accuracy: 0.3597 - loss: 1.7601 - val_accuracy: 0.4257 - val_loss: 1.6078
# Epoch 24/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 40s 33ms/step - accuracy: 0.3721 - loss: 1.7468 - val_accuracy: 0.4021 - val_loss: 1.6539
# Epoch 25/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - accuracy: 0.3651 - loss: 1.7703 - val_accuracy: 0.4229 - val_loss: 1.6028
# Epoch 26/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 35ms/step - accuracy: 0.3693 - loss: 1.7589 - val_accuracy: 0.4212 - val_loss: 1.6219
# Epoch 27/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 35ms/step - accuracy: 0.3746 - loss: 1.7428 - val_accuracy: 0.4262 - val_loss: 1.6297
# Epoch 28/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.3728 - loss: 1.7487 - val_accuracy: 0.4193 - val_loss: 1.6114
# Epoch 29/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 34ms/step - accuracy: 0.3782 - loss: 1.7450 - val_accuracy: 0.4102 - val_loss: 1.6242
# Epoch 30/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 43s 37ms/step - accuracy: 0.3810 - loss: 1.7359 - val_accuracy: 0.4182 - val_loss: 1.6086
# Epoch 31/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 40s 35ms/step - accuracy: 0.3789 - loss: 1.7336 - val_accuracy: 0.4280 - val_loss: 1.6182
# Epoch 32/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 35ms/step - accuracy: 0.3808 - loss: 1.7285 - val_accuracy: 0.4001 - val_loss: 1.6536
# Epoch 33/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 34ms/step - accuracy: 0.3792 - loss: 1.7375 - val_accuracy: 0.4341 - val_loss: 1.5827
# Epoch 34/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 40s 32ms/step - accuracy: 0.3794 - loss: 1.7243 - val_accuracy: 0.4284 - val_loss: 1.6007
# Epoch 35/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.3815 - loss: 1.7219 - val_accuracy: 0.4241 - val_loss: 1.6398
# Epoch 36/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 42s 37ms/step - accuracy: 0.3773 - loss: 1.7298 - val_accuracy: 0.4240 - val_loss: 1.5987
# Epoch 37/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 37ms/step - accuracy: 0.3778 - loss: 1.7353 - val_accuracy: 0.4212 - val_loss: 1.6000
# Epoch 38/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.3887 - loss: 1.7146 - val_accuracy: 0.4247 - val_loss: 1.6170
# Epoch 39/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.3800 - loss: 1.7272 - val_accuracy: 0.4375 - val_loss: 1.5711
# Epoch 40/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - accuracy: 0.3847 - loss: 1.7215 - val_accuracy: 0.4295 - val_loss: 1.6012
# Epoch 41/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 34ms/step - accuracy: 0.3786 - loss: 1.7289 - val_accuracy: 0.4221 - val_loss: 1.6095
# Epoch 42/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 34ms/step - accuracy: 0.3751 - loss: 1.7296 - val_accuracy: 0.4221 - val_loss: 1.6000
# Epoch 43/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 40s 33ms/step - accuracy: 0.3900 - loss: 1.7077 - val_accuracy: 0.4280 - val_loss: 1.5913
# Epoch 44/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 40s 32ms/step - accuracy: 0.3840 - loss: 1.7108 - val_accuracy: 0.4313 - val_loss: 1.5851
# Epoch 45/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 34ms/step - accuracy: 0.3877 - loss: 1.7122 - val_accuracy: 0.4310 - val_loss: 1.5837
# Epoch 46/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.3892 - loss: 1.6985 - val_accuracy: 0.4231 - val_loss: 1.6112
# Epoch 47/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 33ms/step - accuracy: 0.3922 - loss: 1.6975 - val_accuracy: 0.4338 - val_loss: 1.5801
# Epoch 48/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.3966 - loss: 1.6928 - val_accuracy: 0.4319 - val_loss: 1.5860
# Epoch 49/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 35ms/step - accuracy: 0.3955 - loss: 1.6959 - val_accuracy: 0.4374 - val_loss: 1.5670
# Epoch 50/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 35ms/step - accuracy: 0.3903 - loss: 1.6999 - val_accuracy: 0.4302 - val_loss: 1.5957
# Epoch 51/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 40s 34ms/step - accuracy: 0.3874 - loss: 1.7037 - val_accuracy: 0.4233 - val_loss: 1.5938
# Epoch 52/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 40s 32ms/step - accuracy: 0.3926 - loss: 1.6962 - val_accuracy: 0.4253 - val_loss: 1.5986
# Epoch 53/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.3923 - loss: 1.7012 - val_accuracy: 0.4202 - val_loss: 1.6026
# Epoch 54/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.3934 - loss: 1.7041 - val_accuracy: 0.4337 - val_loss: 1.5664
# Epoch 55/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 42s 36ms/step - accuracy: 0.3960 - loss: 1.6974 - val_accuracy: 0.4243 - val_loss: 1.6087
# Epoch 56/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.3932 - loss: 1.7028 - val_accuracy: 0.4169 - val_loss: 1.6268
# Epoch 57/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 40s 32ms/step - accuracy: 0.3930 - loss: 1.6938 - val_accuracy: 0.4251 - val_loss: 1.5940
# Epoch 58/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 34ms/step - accuracy: 0.3908 - loss: 1.7128 - val_accuracy: 0.4197 - val_loss: 1.6451
# Epoch 59/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 42s 36ms/step - accuracy: 0.3928 - loss: 1.6948 - val_accuracy: 0.4167 - val_loss: 1.6200
# Epoch 60/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 35ms/step - accuracy: 0.3938 - loss: 1.7011 - val_accuracy: 0.4370 - val_loss: 1.5736
# Epoch 61/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 40s 34ms/step - accuracy: 0.3931 - loss: 1.7022 - val_accuracy: 0.4176 - val_loss: 1.6291
# Epoch 62/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 40s 33ms/step - accuracy: 0.3851 - loss: 1.7088 - val_accuracy: 0.4236 - val_loss: 1.6144
# Epoch 63/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 33ms/step - accuracy: 0.3970 - loss: 1.6871 - val_accuracy: 0.4424 - val_loss: 1.5652
# Epoch 64/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.3972 - loss: 1.6815 - val_accuracy: 0.4379 - val_loss: 1.5817
# Epoch 65/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 35ms/step - accuracy: 0.3995 - loss: 1.6835 - val_accuracy: 0.4350 - val_loss: 1.5953
# Epoch 66/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 34ms/step - accuracy: 0.3965 - loss: 1.6855 - val_accuracy: 0.4354 - val_loss: 1.5807
# Epoch 67/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 48s 46ms/step - accuracy: 0.3990 - loss: 1.6911 - val_accuracy: 0.4311 - val_loss: 1.5832
# Epoch 68/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 43s 50ms/step - accuracy: 0.3930 - loss: 1.6871 - val_accuracy: 0.4382 - val_loss: 1.5787
# Epoch 69/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 39s 47ms/step - accuracy: 0.3945 - loss: 1.6890 - val_accuracy: 0.4134 - val_loss: 1.6084
# Epoch 70/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 35ms/step - accuracy: 0.4003 - loss: 1.6904 - val_accuracy: 0.4217 - val_loss: 1.6101
# Epoch 71/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.3974 - loss: 1.6901 - val_accuracy: 0.4318 - val_loss: 1.5746
# Epoch 72/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 33ms/step - accuracy: 0.4012 - loss: 1.6859 - val_accuracy: 0.4441 - val_loss: 1.5682
# Epoch 73/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.3994 - loss: 1.6850 - val_accuracy: 0.4390 - val_loss: 1.5656
# Epoch 73: early stopping

# %%
# 문제 3-5: 학습 히스토리의 `loss`, `val_loss`, `accuracy`, `val_accuracy`를 차트로 시각화합니다.
plt.style.use('seaborn-white')
history_dict = history.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']
accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize=(12, 6))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b-', label='Training Loss')
ax1.plot(epochs, val_loss, 'r-', label='Validation Loss')
ax1.set_title('Training and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend()

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, accuracy, 'b-', label='Training Accuracy')
ax2.plot(epochs, val_accuracy, 'r-', label='Validation Accuracy')
ax2.set_title('Training and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.legend()

plt.show()
# Out:
# <ipython-input-32-f4e69a3bb377>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')

# %% [markdown]
# ## 모델 평가 및 예측

# %%
# 테스트 데이터셋을 이용해 모델을 평가합니다.
model.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.4508 - loss: 1.5405
# [1.5477359294891357, 0.448199987411499]
